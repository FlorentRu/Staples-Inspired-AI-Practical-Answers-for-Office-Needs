# %%
# Let's install the Kaggle library in order to import the dataset to train our model
# !pip install -q kaggle

# %%
# !kaggle datasets download -d praneshmukhopadhyay/amazon-questionanswer-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/praneshmukhopadhyay/amazon-questionanswer-dataset
# License(s): CC0-1.0
# Downloading amazon-questionanswer-dataset.zip to /content
#  97% 415M/426M [00:09<00:00, 18.6MB/s]
# 100% 426M/426M [00:09<00:00, 48.8MB/s]

# %%
# !unzip amazon-questionanswer-dataset.zip
# Out:
# Archive:  amazon-questionanswer-dataset.zip
#   inflating: multi_answers.csv
#   inflating: multi_questions.csv
#   inflating: single_qna.csv

# %%
# Let's install Kaggle CLI
# !pip install --quiet kaggle

# Let's create a ~/.kaggle folder and move kaggle.json there
import os
os.makedirs('/root/.kaggle', exist_ok=True)
# !cp /content/kaggle.json /root/.kaggle/

# Let's permissions
# !chmod 600 /root/.kaggle/kaggle.json

# Lets download the dataset from Kaggle

# %%
# !ls
# Out:
# amazon-questionanswer-dataset.zip  multi_questions.csv	single_qna.csv
# multi_answers.csv		   sample_data

# %%
import pandas as pd

df_multi_answers = pd.read_csv("multi_answers.csv")
df_multi_questions = pd.read_csv("multi_questions.csv")
df_single_qna = pd.read_csv("single_qna.csv")

print("=== multi_answers.csv ===")
display(df_multi_answers.head(3))

print("=== multi_questions.csv ===")
display(df_multi_questions.head(3))

print("=== single_qna.csv ===")
display(df_single_qna.head(3))
# Out:
# === multi_answers.csv ===
#   QuestionID                                         AnswerText  \
# 0       C1Q1  It's all custom mounting, where there's a will...
# 1       C1Q1  You will need to drill another hole in Mud fla...
# 2       C1Q1  It's been a while since I installed them, but ...
#
#        AnswererID         AnswerTime AnswerType  AnswerScore
# 0   AQZ8QLPPYA359  December 29, 2014        NaN          NaN
# 1  A246IDL7UXVCQO  December 29, 2014        NaN          NaN
# 2  A3BWPG98KF0TAV      July 19, 2013          ?       0.5428
# === multi_questions.csv ===
#   QuestionID QuestionType    Category         AskerID   QuestionTime  \
# 0       C1Q1       yes/no  Automotive  A365S8H55GGXPD  July 19, 2013
# 1       C1Q2       yes/no  Automotive   AXOOEUYEJ87ZB    May 7, 2014
# 2       C1Q3   open-ended  Automotive   AN2AMELSNPN99  June 20, 2014
#
#                             QuestionText
# 0         will they fit 2013 f350 dually
# 1      will they fit 2014 mazda 3 sport?
# 2  Do they fit a 1998 GMC Sierra 3 door?
# === single_qna.csv ===
#   QuestionType        Asin    AnswerTime      UnixTime  \
# 0       yes/no  B00004U9JP  Jun 27, 2014  1.403852e+09
# 1   open-ended  B00004U9JP  Apr 28, 2014  1.398668e+09
# 2       yes/no  B00004U9JP  Aug 25, 2014  1.408950e+09
#
#                                             Question AnswerType  \
# 0  I have a 9 year old Badger 1 that needs replac...          ?
# 1                                       model number        NaN
# 2  can I replace Badger 1 1/3 with a Badger 5 1/2...          ?
#
#                                               Answer    Category
# 0   I replaced my old one with this without a hitch.  Appliances
# 1  This may help InSinkErator Model BADGER-1: Bad...  Appliances
# 2  Plumbing connections will vary with different ...  Appliances

# %%
# Here's an example join on "QuestionID"
df_joine
# Out:
# Joined DataFrame shape: (4019744, 11)
#   QuestionID QuestionType    Category         AskerID   QuestionTime  \
# 0       C1Q1       yes/no  Automotive  A365S8H55GGXPD  July 19, 2013
# 1       C1Q1       yes/no  Automotive  A365S8H55GGXPD  July 19, 2013
# 2       C1Q1       yes/no  Automotive  A365S8H55GGXPD  July 19, 2013
# 3       C1Q1       yes/no  Automotive  A365S8H55GGXPD  July 19, 2013
# 4       C1Q1       yes/no  Automotive  A365S8H55GGXPD  July 19, 2013
#
#                      QuestionText  \
# 0  will they fit 2013 f350 dually
# 1  will they fit 2013 f350 dually
# 2  will they fit 2013 f350 dually
# 3  will they fit 2013 f350 dually
# 4  will they fit 2013 f350 dually
#
#                                           AnswerText      AnswererID  \
# 0  It's all custom mounting, where there's a will...   AQZ8QLPPYA359
# 1  You will need to drill another hole in Mud fla...  A246IDL7UXVCQO
# 2  It's been a while since I installed them, but ...  A3BWPG98KF0TAV
# 3           1 pair rear flaps and mounting hardware.               1
# 4  I didn't buy these for myself I bought them fo...  A1MGZTOLD2C0VS
#
#           AnswerTime AnswerType  AnswerScore
# 0  December 29, 2014        NaN          NaN
# 1  December 29, 2014        NaN          NaN
# 2      July 19, 2013          ?       0.5428
# 3      July 19, 2013          ?       0.5565
# 4      July 19, 2013          ?       0.4623

# %%
def create_qa_chunk(row):
    question = str(row["QuestionText"])
    answers_list = row["AnswerText"]

    # Casting each answer to string
    answers_list = [str(ans) for ans in answers_list]

    answers_str = "\n- " + "\n- ".join(answers_list)
    combined_text = f"Q: {question}\nAnswers:{answers_str}"
    return combined_text

# %%
def create_qa_chunk(row):
    question = str(row["QuestionText"])
    answers_list = row["AnswerText"]

    # Replace NaN floats with a placeholder as we walk through data processing step
    answers_list = [str(ans) if pd.notna(ans) else "No Answer" for ans in answers_list]

    answers_str = "\n- " + "\n- ".join(answers_list)
    combined_text = f"Q: {question}\nAnswers:{answers_str}"
    return combined_text

# %%
# Convert AnswerText to string, replacing NaN
df_joined["AnswerText"] = df_joined["AnswerText"].fillna("No Answer").astype(str)

# %%
# 1. Group all answers for each question
df_grouped = (
    df_joined.groupby(["QuestionID", "QuestionText"])["AnswerText"]
    .apply(list)
    .reset_index()
)

# 2. Let's combine them into one chunk of text
def create_qa_chunk(row):
    question = str(row["QuestionText"])
    answers_list = row["AnswerText"]
    answers_str = "\n- " + "\n- ".join(answers_list)
    combined_text = f"Q: {question}\nAnswers:{answers_str}"
    return combined_text

df_grouped["combined_text"] = df_grouped.apply(create_qa_chunk, axis=1)
df_grouped.head()
# Out:
#   QuestionID                                       QuestionText  \
# 0      C10Q1  Would a sennheiser HMD280-13 and this adapter ...
# 1     C10Q10  I just received my first tube/stick of Fast Fr...
# 2    C10Q100                               Are these in a pair?
# 3   C10Q1000  Can I use such a LED strip (to replace old inc...
# 4   C10Q1001  What is the width of the string spacing at the...
#
#                                           AnswerText  \
# 0  [I took a photo: <http://imgur.com/G48f1C4>I b...
# 1  [I've never actually used guitar honey but I w...
# 2  [You need to use speaker cables....NOT guitar ...
# 3  [The specifications for the 5Meter LED light s...
# 4  [Black pegs. Thank you,AdamGTRSTORE646-460-847...
#
#                                        combined_text
# 0  Q: Would a sennheiser HMD280-13 and this adapt...
# 1  Q: I just received my first tube/stick of Fast...
# 2  Q: Are these in a pair?\nAnswers:\n- You need ...
# 3  Q: Can I use such a LED strip (to replace old ...
# 4  Q: What is the width of the string spacing at ...

# %%
# !pip install --quiet langchain==0.0.137 faiss-cpu sentence-transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.6/153.6 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.3/518.3 kB 19.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 22.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 70.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 3.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.20 requires pydantic>=2.7.0, but you have pydantic 1.10.20 which is incompatible.
# google-genai 0.3.0 requires pydantic<3.0.0dev,>=2.0.0, but you have pydantic 1.10.20 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.54 which is incompatible.
# langchain-core 0.3.29 requires pydantic<3.0.0,>=2.5.2; python_full_version < "3.12.4", but you have pydantic 1.10.20 which is incompatible.
# wandb 0.19.1 requires pydantic<3,>=2.6, but you have pydantic 1.10.20 which is incompatible.

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

# 1. Now let's pick an embedding model from Hugging Face
embedding_model_name = "sentence-transformers/all-MiniLM-L6-v2"
hf_embeddings = HuggingFaceEmbeddings(model_name=embedding_model_name)

# 2. Converting combined_text into a list
docs = df_grouped["combined_text"].tolist()

# 3. Building FAISS index
vectorstore = FAISS.from_texts(docs, hf_embeddings)
print("FAISS index created with", len(docs), "entries.")
# Out:
# FAISS index created with 172617 entries.

# %%
query = "Will these mud flaps fit a Ford F150?"
results = vectorstore.similarity_search(query, k=2)

for i, doc in enumerate(results):
    print(f"--- Result {i+1} ---")
    print(doc.page_content)
    print()
# Out:
# --- Result 1 ---
# Q: will these work with mud flaps?
# Answers:
# - Mine were OEM Ford liners. Included all new hardware too.
# - Ford FactoryVery good fit
# - These are OEM not aftermarket
# - Ford OEM accessory.
# - I think so, but they couldn't fit more perfectly. I would definately recommend them.
# - They are factory wheel liners from ford.  They fit and work perfectly.
# - Original Ford factory liners
# - They are Ford OEM.
# - they are original ford.  You can order a truck with them installed or the dealer sells and installs the same part.
# - Yes they're aftermarket.
# - Yes, I have a 2013 F150 Platinum model.  They fit perfectly, and they are easy to install without removing the wheels.
# - Yes they do ...
# - Yes, just put a set on my 2013 f150...Matt
# - Yes, they are on mine.
# - Yes, they will fit very well. Had to jack up the back of the truck from under the trailer hitch for acsess. Do it on a warm day, you don't want hard plastic.
# - YES THEY WILL!THANKS
# - yes
# - Yes they will fit... 2014 is the last year they will fit...
# - Yes.  I put them on my 2014. Worth every penny.
# - You should have no problems. I have a 2013 and there  is no changes for 2014.
# - I believe they will
# - Yes they fit. These are manufactured by Ford so I went to accessories.ford.com and put in your vehicle information. The part numbers on the site and the part numbers listed here match so they will fit.
# - Yes they will it's the same size as the 4x4
# - It should fit.
# - Yes, I just put them on my 2014 XLT and they fit perfectly and look great. Remove the tire first and it is EZ. Sketch directions are a waste of time until you have them installed then they become obvious.Installation on a warm day with the liners in the sun for a time also makes it much easier.
# - yes they fit very well ,mine is a 2014 f 150 xlt easy to install also
# - I'm NOT 100% but I don't see why not.  Check online at tascaparts.com, to get the part number, then order from Amazon, that's what I did...Also, super easy install, about an hour, without removing the wheels, tire.  good luck.
# - Yes! Anad they look great. Better than without having them in place.
# - Yes they work great i put them on my 2014 f 150. 4x4 they make the truck look better to
# - Yes they will fit i installed them on my 2014 XLT 4x4 and my sons 2014 FX4
# - Yes they will fit and they are great
# - Yes!
# - My suggestion is to visit the Ford's accessories website and enter your truck information for these covers. Compare the part number there to the one here. These are made by Ford so the numbers will match if it fits your vehicle.
# - These fit 2004 to 2014 Ford F-150. Just installed these in a 2014 and they fit perfectly.
# - I'm sure they will. They are farely easy to test so if they don't u can just return them and let them know if they fit or don't for future reference
# - yes
# - these are the as Ford OEM - i installed fhese on my 2013 limited - no problem - these were the same as Ford had as options - less $$
# - Yes!  I have a 2014 XLT and a 2013 Lariat both fit the liners great!!!!  I recommend the purchase.
# - Yes , worked fine with front and rear ford mud flaps
# - Yes. I installed Weathertech mud flaps right after installing the fender liners. I have a 2013 F150.
# - Yes they do not interfere with ford mud flaps or  weathertechs
# - Yes
#
# --- Result 2 ---
# Q: do they fit 1999 f150 flair side ?
# Answers:
# - Yes, mine came as a set of four, individually wrapped and labeled for each location.
# - Yes it is and they fit great.
# - yes it is!
# - No it is a set of two. I needed to two sets for my cab.
# - Tape and self tapping screws.
# - Yes all mounting hardware is included.  Double sided taped is used on the top and screws on the bottom.
# - Bolt on and tape at top there great easy to put on
# - They use double sided tape and self tapping screws. Get yourself some 3m double sided tape, it holds much better than the tape that comes on the flares.
# - self tapping srews and adhesive on the fender
# - I have the same mud flaps .. I hald them up there it looks like they will work . I want to to get some self tapping srews before I put my back on .I hope it helps you
# - I was able to reuse my factory mad flaps
# - Not sure what you have, but I had plastic molded mudflaps with white Ford logo.  Had to remove them to install these flares.  My flaps may be possible to reinstall but I opted just to leave off.
# - I was very pleased when i ordered i recived 4 of them.....and they fit amazingly
# - They come with all four. They cover about 3" of the fender. Very nice product.
# - Yes they did cover easy to install
# - All 4 pcs.with set
# - They come in sets of 4 & cover about 3 inchs
# - It's a set of 4 and they go up to the first bend of the wheel whel
# - They come with all 4
# - it comes with 4 of them
# - It comes with all four...these are identical to the factory ones. The fit is nice andthey are smooth finish also so they can be painted to match. Hope that helps.
# - I had the same problem on the rear. They did the trick. 3" should be fine
# - It would be close. Maybe not 3 inches
# - rust, rear fenders I'll bet,  I had same problem, they fit perfect, they cover 3 -1/4 "  inches up
# - Covers 3 1/2 inches.
# - 1/2 inch. Comaparable to the factory wheel well trim.
# - very little, it's just like the oem ones you get from ford. I have 20 x 12 wide tires and they are just enough flare for those tires on my f 350. hope this helps  you out.  john
# - Not much at all .. They look like the stock King ranch or limited edition o.e.m style
# - Inch maybe inch a half
# - They don't stick out at all but they do dress the truck nice an they only cover 2 inches of rust so if you have a lot of rust you need taller ones but for Looks there awesome
# - probably add 1/2 inch to 3/4 inch past fender, the contour fit is good and they look like they belong
# - About 1/2'' to 1''
# - not much maybe 1/4 inch.  I put them on mainly to cover up rust coming through rear fenders. lol
# - No, it will not. It will fit a 1999 F250.
# - No they won't fit
# - no they will not, the f-150 will have different front and rear fenders
# - No. These will only fit on Super Duty Models 99-04

# %%
# Ignoring this snippet as it is a debugging step
# from huggingface_hub import login
# login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !pip install huggingface_hub
from huggingface_hub import login

login()
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.12.14)
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch

MODEL_ID = "tiiuae/falcon-7b-instruct"

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, use_fast=False)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    torch_dtype=torch.float16,
    device_map="auto"
)

llama_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/17.7k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.48G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/117 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# Device set to use cuda:0

# %%
def ask_model(question: str) -> str:
    """
    A placeholder function that sends 'question' to the model/pipeline
    and returns the response as a string.
    """
    # If using Transformers pipeline directly:
    # result = falcon_pipeline(question)[0]["generated_text"]
    # return result

    # OR if using a chain:
    # result = chain.run(question)
    # return result

    # Demo stub: just echo the question
    return "Demo response for: " + question

# A list of queries to test various capabilities of the model
test_queries = [
    # General Knowledge
    "Who was the 16th President of the United States, and what were his main accomplishments?",
    # Reasoning & Problem-Solving
    "If a car travels at 60 mph, how long does it take to go 180 miles?",
    # Summarization
    "Summarize the following text: 'Large language models are transforming how we build AI applications.'",
    # Creative Prompt
    "Write a short story about a time-traveling inventor who lands in ancient Egypt. Keep it under 200 words.",
    # Technical Explanation
    "Explain what a binary search algorithm is and how it works in simple terms.",
    # Multi-step Instructions
    "Give me a step-by-step guide to baking chocolate chip cookies.",
    # Opinion/Argumentation
    "Should governments prioritize spending on space exploration or healthcare? Provide arguments for both sides.",
    # Code Generation
    "Write a Python function to check if a string is a palindrome.",
    # Domain Knowledge
    "What is photosynthesis, and why is it important for life on Earth?",
    # Additional
    "Explain the concept of quantum mechanics to a 10-year-old."
]

# Now let's loop through each query, ask the model, and print the answer
for idx, query in enumerate(test_queries, 1):
    print(f"--- Query {idx}: {query}")
    response = ask_model(query)
    print("Model Response:", response, "\n")
# Out:
# --- Query 1: Who was the 16th President of the United States, and what were his main accomplishments?
# Model Response: Demo response for: Who was the 16th President of the United States, and what were his main accomplishments?
#
# --- Query 2: If a car travels at 60 mph, how long does it take to go 180 miles?
# Model Response: Demo response for: If a car travels at 60 mph, how long does it take to go 180 miles?
#
# --- Query 3: Summarize the following text: 'Large language models are transforming how we build AI applications.'
# Model Response: Demo response for: Summarize the following text: 'Large language models are transforming how we build AI applications.'
#
# --- Query 4: Write a short story about a time-traveling inventor who lands in ancient Egypt. Keep it under 200 words.
# Model Response: Demo response for: Write a short story about a time-traveling inventor who lands in ancient Egypt. Keep it under 200 words.
#
# --- Query 5: Explain what a binary search algorithm is and how it works in simple terms.
# Model Response: Demo response for: Explain what a binary search algorithm is and how it works in simple terms.
#
# --- Query 6: Give me a step-by-step guide to baking chocolate chip cookies.
# Model Response: Demo response for: Give me a step-by-step guide to baking chocolate chip cookies.
#
# --- Query 7: Should governments prioritize spending on space exploration or healthcare? Provide arguments for both sides.
# Model Response: Demo response for: Should governments prioritize spending on space exploration or healthcare? Provide arguments for both sides.
#
# --- Query 8: Write a Python function to check if a string is a palindrome.
# Model Response: Demo response for: Write a Python function to check if a string is a palindrome.
#
# --- Query 9: What is photosynthesis, and why is it important for life on Earth?
# Model Response: Demo response for: What is photosynthesis, and why is it important for life on Earth?
#
# --- Query 10: Explain the concept of quantum mechanics to a 10-year-old.
# Model Response: Demo response for: Explain the concept of quantum mechanics to a 10-year-old.

# %%
from transformers import pipeline

falcon_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=256,
    temperature=0.7
)
# Out:
# Device set to use cuda:0

# %%
# Let's pick some general questions as example queries
test_queries = [
    "Who was the 16th President of the United States, and what were his main accomplishments?",
    "If a car travels at 60 mph, how long does it take to go 180 miles?",
    "Write a short story about a time-traveling inventor who lands in ancient Egypt. Keep it under 200 words.",
    "Explain what a binary search algorithm is and how it works.",
    "Should governments prioritize spending on space exploration or healthcare? Provide arguments for both sides."
]

# Here's the unction to query the Falcon pipeline
def ask_falcon(question: str) -> str:
    # The pipeline returns a list of dicts
    output = falcon_pipeline(question)
    # Extract the generated text from the first dict
    return output[0]["generated_text"]

# Loop through queries, get model-generated answers
for idx, q in enumerate(test_queries, 1):
    print(f"--- Question {idx} ---")
    print("Q:", q)
    answer = ask_falcon(q)
    print("A:", answer)
    print()

    #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_009#
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:628: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# --- Question 1 ---
# Q: Who was the 16th President of the United States, and what were his main accomplishments?
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# A: Who was the 16th President of the United States, and what were his main accomplishments?
# The 16th President of the United States was Abraham Lincoln. His main accomplishments include abolishing slavery in the United States, preserving the Union during the Civil War, and implementing policies that led to economic recovery after the war.
#
# --- Question 2 ---
# Q: If a car travels at 60 mph, how long does it take to go 180 miles?
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# A: If a car travels at 60 mph, how long does it take to go 180 miles?
# To calculate the time it takes to travel 180 miles at 60 mph, you can use the formula: Distance = Speed x Time. In this case, the distance is 180 miles and the speed is 60 mph. So, the time it takes is 180 miles ÷ 60 mph = 3 hours.
#
# --- Question 3 ---
# Q: Write a short story about a time-traveling inventor who lands in ancient Egypt. Keep it under 200 words.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# A: Write a short story about a time-traveling inventor who lands in ancient Egypt. Keep it under 200 words.
# Dr. Aiden awoke to the sound of his time-traveling device, the Arcane Anomaly, emitting a faint humming. He rubbed his eyes, adjusting to the dim light filtering in through the window. Outside, the ancient Egyptian city of Thebes stretched before him, its temples and pyramids casting long shadows. With a curious mind and a pocket full of modern tools, Aiden ventured out to explore this ancient world. He met wise priests and learned the secrets of the afterlife, all while marveling at the marvels of this bygone era.
#
# --- Question 4 ---
# Q: Explain what a binary search algorithm is and how it works.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# A: Explain what a binary search algorithm is and how it works.
# A binary search algorithm is a type of search algorithm that searches a sorted list or array for a specific value or element. It works by repeatedly checking the middle element of the list or array until the target value is found or the search is complete. The algorithm takes advantage of the fact that the list or array is sorted, as it eliminates the need to compare each element with the target value. The middle element is compared with the target value, and if they match, the algorithm returns the index of the target value. If the middle element is less than the target value, the algorithm proceeds to the left half of the list or array. If the middle element is greater than the target value, the algorithm proceeds to the right half of the list or array. This process is repeated until the target value is found or the search is complete.
#
# --- Question 5 ---
# Q: Should governments prioritize spending on space exploration or healthcare? Provide arguments for both sides.
# A: Should governments prioritize spending on space exploration or healthcare? Provide arguments for both sides.
# Governments should prioritize spending on space exploration as it offers long-term benefits, such as developing new technologies, discovering resources, and expanding our knowledge of the universe. Additionally, space exploration has historically been a driver of innovation and economic growth. On the other hand, investing in healthcare is crucial for the well-being of citizens and should not be neglected. Healthcare spending can improve overall quality of life and reduce long-term costs by preventing or managing chronic diseases.

# %%
from langchain.llms import HuggingFacePipeline
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate

# Wrapping our pipeline in a LangChain LLM
llm = HuggingFacePipeline(pipeline=falcon_pipeline)

# Let's define how we want to prompt the model
prompt = PromptTemplate(
    input_variables=["question"],
    template="You are a helpful AI assistant. Answer the question: {question}"
)

chain = LLMChain(
    llm=llm,
    prompt=prompt
)

test_queries = [
    "What are the most cost-effective ways to set up a new small business office, including furniture, equipment, and supplies.",
    "How do I choose the right printer for a small or home office, balancing upfront cost vs. ongoing ink expenses."
]

for idx, q in enumerate(test_queries, 1):
    print(f"--- Question {idx} ---")
    print("Q:", q)
    # chain.run(...) passes the 'question' to our prompt template
    answer = chain.run({"question": q})
    print("A:", answer)
    print()
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# --- Question 1 ---
# Q: What are the most cost-effective ways to set up a new small business office, including furniture, equipment, and supplies.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# A:
# There are several cost-effective ways to set up a new small business office. First, consider using used or refurbished furniture and equipment, which can often be found at a lower cost than new items. Second, look for deals on office supplies, such as discount stores or online retailers. Third, consider renting a shared office space instead of purchasing or leasing expensive commercial property. Finally, think creatively about repurposing existing items for office use, such as using a storage shed for file cabinets or using a bookshelf as a partition for a work area.
#
# --- Question 2 ---
# Q: How do I choose the right printer for a small or home office, balancing upfront cost vs. ongoing ink expenses.
# A:
# When choosing a printer for a small or home office, consider the following factors: 1) Your printing needs - determine if you need a printer that can handle large volumes or if a single-use printer is sufficient. 2) Upfront cost - compare the cost of purchasing a printer versus the ongoing cost of ink or toner. 3) Ongoing cost - consider the cost of ink or toner over time, as well as any additional features or functionalities you may require. 4) Connectivity - ensure the printer is compatible with your devices and has the necessary ports for connectivity. 5) Brand reputation - choose a printer from a reputable brand with a good track record for reliability. 6) Print quality - opt for a printer with high-quality print resolution to ensure crisp and clear prints. 7) Energy efficiency - choose a printer with power-saving features to reduce your electricity usage.
